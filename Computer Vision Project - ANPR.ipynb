# %%
pip install imutils easyocr
# Out:
# Requirement already satisfied: imutils in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: easyocr in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: pyclipper in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: ninja in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: Pillow in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (9.4.0)
# Requirement already satisfied: opencv-python-headless in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (4.7.0.72)
# Requirement already satisfied: scikit-image in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (0.21.0)
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (1.22.1)
# Requirement already satisfied: torch in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: torchvision>=0.5 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (0.15.2)
# Requirement already satisfied: python-bidi in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: Shapely in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: scipy in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: PyYAML in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from easyocr) (6.0)
# Requirement already satisfied: requests in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: filelock in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from torch->easyocr) (3.12.2)
# Requirement already satisfied: sympy in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from torch->easyocr) (4.6.3)
# Requirement already satisfied: networkx in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: six in /opt/homebrew/Cellar/six/1.16.0_3/lib/python3.10/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from scikit-image->easyocr) (2.31.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from scikit-image->easyocr) (2023.4.12)
# Requirement already satisfied: packaging>=21 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from packaging>=21->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from jinja2->torch->easyocr) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.24)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from sympy->torch->easyocr) (1.3.0)
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages (from opencv-python) (1.22.1)
#
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr
import os

# %%
absolute_path = os.path.join(os.getcwd(), 'google_images', '0c9ebe94-827d-4c74-9950-6816e70d1bab___IMG_8883.jpg.jpeg');
img = cv2.imread(absolute_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(img, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
print(location)
# Out:
# [[[159 109]]
#
#  [[348 112]]
#
#  [[331 157]]
#
#  [[174 154]]]

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
print(result)
# Out:
# [([[29, 7], [162, 7], [162, 38], [29, 38]], 'MH2OBY36 65', 0.846726059763465)]

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %%
print(text)
# Out:
# MH2OBY36 65
